# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
df_raw =  pd.read_excel('séries_AirLiquide.xlsx')
df_raw
# Out:
#     Unnamed: 0  Div AirLiquide (lissé)  Prix Airliquide  Indice CAC40
# 0      1987M03                0.305684          11.1670           NaN
# 1      1987M04                0.306773          11.8679           NaN
# 2      1987M05                0.307862          11.3422           NaN
# 3      1987M06                0.308952          11.0714           NaN
# 4      1987M07                0.310043          10.9918           NaN
# ..         ...                     ...              ...           ...
# 392    2019M11                2.465649         118.4500       5761.89
# 393    2019M12                2.474304         119.6000       5786.74
# 394    2020M01                2.482985         126.7000       6041.50
# 395    2020M02                2.491688         131.9000       5832.51
# 396    2020M03                2.500406         125.0500       5333.52
#
# [397 rows x 4 columns]

# %%
df = df_raw
df
# Out:
#     Unnamed: 0  Div AirLiquide (lissé)  Prix Airliquide  Indice CAC40
# 0      1987M03                0.305684          11.1670           NaN
# 1      1987M04                0.306773          11.8679           NaN
# 2      1987M05                0.307862          11.3422           NaN
# 3      1987M06                0.308952          11.0714           NaN
# 4      1987M07                0.310043          10.9918           NaN
# ..         ...                     ...              ...           ...
# 392    2019M11                2.465649         118.4500       5761.89
# 393    2019M12                2.474304         119.6000       5786.74
# 394    2020M01                2.482985         126.7000       6041.50
# 395    2020M02                2.491688         131.9000       5832.51
# 396    2020M03                2.500406         125.0500       5333.52
#
# [397 rows x 4 columns]

# %%
df['year']=[x.split("M")[0] for x in df['Unnamed: 0']]
df['month']=[x.split("M")[1] for x in df['Unnamed: 0']]
df
# Out:
#     Unnamed: 0  Div AirLiquide (lissé)  Prix Airliquide  Indice CAC40  year  \
# 0      1987M03                0.305684          11.1670           NaN  1987
# 1      1987M04                0.306773          11.8679           NaN  1987
# 2      1987M05                0.307862          11.3422           NaN  1987
# 3      1987M06                0.308952          11.0714           NaN  1987
# 4      1987M07                0.310043          10.9918           NaN  1987
# ..         ...                     ...              ...           ...   ...
# 392    2019M11                2.465649         118.4500       5761.89  2019
# 393    2019M12                2.474304         119.6000       5786.74  2019
# 394    2020M01                2.482985         126.7000       6041.50  2020
# 395    2020M02                2.491688         131.9000       5832.51  2020
# 396    2020M03                2.500406         125.0500       5333.52  2020
#
#     month
# 0      03
# 1      04
# 2      05
# ...

# %%
format_wanted = '%m-%Y'
df['Datetime'] = pd.to_datetime(df['month'] + '-' + df['year'], format=format_wanted)
df = df.set_index(pd.DatetimeIndex(df['Datetime']))
df
# Out:
#            Unnamed: 0  Div AirLiquide (lissé)  Prix Airliquide  Indice CAC40  \
# Datetime
# 1987-03-01    1987M03                0.305684          11.1670           NaN
# 1987-04-01    1987M04                0.306773          11.8679           NaN
# 1987-05-01    1987M05                0.307862          11.3422           NaN
# 1987-06-01    1987M06                0.308952          11.0714           NaN
# 1987-07-01    1987M07                0.310043          10.9918           NaN
# ...               ...                     ...              ...           ...
# 2019-11-01    2019M11                2.465649         118.4500       5761.89
# 2019-12-01    2019M12                2.474304         119.6000       5786.74
# 2020-01-01    2020M01                2.482985         126.7000       6041.50
# 2020-02-01    2020M02                2.491688         131.9000       5832.51
# 2020-03-01    2020M03                2.500406         125.0500       5333.52
#
#             year month   Datetime
# ...

# %%
df.drop(columns = ["Datetime","year","month","Unnamed: 0"],inplace=True)
df
# Out:
#             Div AirLiquide (lissé)  Prix Airliquide  Indice CAC40
# Datetime
# 1987-03-01                0.305684          11.1670           NaN
# 1987-04-01                0.306773          11.8679           NaN
# 1987-05-01                0.307862          11.3422           NaN
# 1987-06-01                0.308952          11.0714           NaN
# 1987-07-01                0.310043          10.9918           NaN
# ...                            ...              ...           ...
# 2019-11-01                2.465649         118.4500       5761.89
# 2019-12-01                2.474304         119.6000       5786.74
# 2020-01-01                2.482985         126.7000       6041.50
# 2020-02-01                2.491688         131.9000       5832.51
# 2020-03-01                2.500406         125.0500       5333.52
#
# [397 rows x 3 columns]

# %%
df['Dividend'] = df['Div AirLiquide (lissé)']
df['Price'] = df['Prix Airliquide']
df['CAC40_basis_points'] = df['Indice CAC40']
df.drop(columns = ['Div AirLiquide (lissé)','Prix Airliquide','Indice CAC40'],inplace=True)
df
# Out:
#             Dividend     Price  CAC40_basis_points
# Datetime
# 1987-03-01  0.305684   11.1670                 NaN
# 1987-04-01  0.306773   11.8679                 NaN
# 1987-05-01  0.307862   11.3422                 NaN
# 1987-06-01  0.308952   11.0714                 NaN
# 1987-07-01  0.310043   10.9918                 NaN
# ...              ...       ...                 ...
# 2019-11-01  2.465649  118.4500             5761.89
# 2019-12-01  2.474304  119.6000             5786.74
# 2020-01-01  2.482985  126.7000             6041.50
# 2020-02-01  2.491688  131.9000             5832.51
# 2020-03-01  2.500406  125.0500             5333.52
#
# [397 rows x 3 columns]

# %%
stock ='AI.PA'
ticker = yf.Ticker(stock)
info = ticker.info
beta = info.get('beta')
beta
# Out:
# 0.645825

# %%
df['Dividend'].rolling(window=12).mean()
# Out:
# Datetime
# 1987-03-01         NaN
# 1987-04-01         NaN
# 1987-05-01         NaN
# 1987-06-01         NaN
# 1987-07-01         NaN
#                 ...
# 2019-11-01    2.418003
# 2019-12-01    2.426729
# 2020-01-01    2.435424
# 2020-02-01    2.444099
# 2020-03-01    2.452763
# Name: Dividend, Length: 397, dtype: float64

# %%
ail = yf.Ticker(stock)

# get all stock info
ail.info

# get historical market data
hist = ail.history(period="1mo")
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-06-14 00:00:00+02:00  158.660004  160.279999  158.460007  159.580002
# 2023-06-15 00:00:00+02:00  159.320007  160.479996  158.960007  160.300003
# 2023-06-16 00:00:00+02:00  160.979996  167.940002  160.419998  167.940002
# 2023-06-19 00:00:00+02:00  164.199997  164.199997  161.039993  161.500000
# 2023-06-20 00:00:00+02:00  160.740005  162.479996  159.919998  161.520004
# 2023-06-21 00:00:00+02:00  161.059998  161.580002  160.160004  160.880005
# 2023-06-22 00:00:00+02:00  160.000000  160.059998  157.720001  160.000000
# 2023-06-23 00:00:00+02:00  159.399994  159.660004  156.979996  158.580002
# 2023-06-26 00:00:00+02:00  158.720001  160.360001  158.119995  159.720001
# 2023-06-27 00:00:00+02:00  160.259995  160.839996  159.000000  160.679993
# 2023-06-28 00:00:00+02:00  161.580002  162.619995  161.179993  162.500000
# 2023-06-29 00:00:00+02:00  162.699997  163.500000  161.779999  163.199997
# ...

# %%
sp500 = yf.Ticker('^FCHI')

# get all stock info
sp500.info

# get historical market data
hist = sp500.history(period="1mo")
hist
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2023-06-15 00:00:00-04:00  4365.330078  4439.200195  4362.600098  4425.839844
# 2023-06-16 00:00:00-04:00  4440.950195  4448.470215  4407.439941  4409.589844
# 2023-06-20 00:00:00-04:00  4396.109863  4400.149902  4367.189941  4388.709961
# 2023-06-21 00:00:00-04:00  4380.009766  4386.220215  4360.140137  4365.689941
# 2023-06-22 00:00:00-04:00  4355.399902  4382.250000  4351.819824  4381.890137
# 2023-06-23 00:00:00-04:00  4354.169922  4366.549805  4341.339844  4348.330078
# 2023-06-26 00:00:00-04:00  4344.839844  4362.060059  4328.080078  4328.819824
# 2023-06-27 00:00:00-04:00  4337.359863  4384.419922  4335.000000  4378.410156
# 2023-06-28 00:00:00-04:00  4367.479980  4390.350098  4360.220215  4376.859863
# 2023-06-29 00:00:00-04:00  4374.939941  4398.390137  4371.970215  4396.439941
# 2023-06-30 00:00:00-04:00  4422.439941  4458.479980  4422.439941  4450.379883
# ...
