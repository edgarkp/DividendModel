# %% [markdown]
# ### 1- Download the necessary modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %% [markdown]
# ### 2- Import the data in excel file and format them

# %%
df_raw =  pd.read_excel('séries_AirLiquide.xlsx',sheet_name ='part1')
df_raw.head(10)
# Out:
#   Unnamed: 0  Div AirLiquide (lissé)  Prix Airliquide  Indice CAC40
# 0    1987M03                0.305684          11.1670           NaN
# 1    1987M04                0.306773          11.8679           NaN
# 2    1987M05                0.307862          11.3422           NaN
# 3    1987M06                0.308952          11.0714           NaN
# 4    1987M07                0.310043          10.9918           NaN
# 5    1987M08                0.311138          11.1511       1483.02
# 6    1987M09                0.312236          11.0873       1524.00
# 7    1987M10                0.313339          10.8962       1456.88
# 8    1987M11                0.314448           8.5226       1116.47
# 9    1987M12                0.315563           7.9969       1026.98

# %%
df = df_raw
df.head(10)
# Out:
#   Unnamed: 0  Div AirLiquide (lissé)  Prix Airliquide  Indice CAC40
# 0    1987M03                0.305684          11.1670           NaN
# 1    1987M04                0.306773          11.8679           NaN
# 2    1987M05                0.307862          11.3422           NaN
# 3    1987M06                0.308952          11.0714           NaN
# 4    1987M07                0.310043          10.9918           NaN
# 5    1987M08                0.311138          11.1511       1483.02
# 6    1987M09                0.312236          11.0873       1524.00
# 7    1987M10                0.313339          10.8962       1456.88
# 8    1987M11                0.314448           8.5226       1116.47
# 9    1987M12                0.315563           7.9969       1026.98

# %% [markdown]
# ### 3- Preprocessing

# %%
df['year']=[x.split("M")[0] for x in df['Unnamed: 0']]
df['month']=[x.split("M")[1] for x in df['Unnamed: 0']]
df.head(10)
# Out:
#   Unnamed: 0  Div AirLiquide (lissé)  Prix Airliquide  Indice CAC40  year  \
# 0    1987M03                0.305684          11.1670           NaN  1987
# 1    1987M04                0.306773          11.8679           NaN  1987
# 2    1987M05                0.307862          11.3422           NaN  1987
# 3    1987M06                0.308952          11.0714           NaN  1987
# 4    1987M07                0.310043          10.9918           NaN  1987
# 5    1987M08                0.311138          11.1511       1483.02  1987
# 6    1987M09                0.312236          11.0873       1524.00  1987
# 7    1987M10                0.313339          10.8962       1456.88  1987
# 8    1987M11                0.314448           8.5226       1116.47  1987
# 9    1987M12                0.315563           7.9969       1026.98  1987
#
#   month
# 0    03
# 1    04
# 2    05
# 3    06
# 4    07
# 5    08
# 6    09
# 7    10
# 8    11
# 9    12

# %%
# Change to annual values
df_yearly = pd.DataFrame() 

dividend_yearly = df.groupby('year')['Div AirLiquide (lissé)'].mean().round(3)
df_yearly['Dividend'] = dividend_yearly

price_yearly = df.groupby('year')['Prix Airliquide'].mean().round(3)
df_yearly['Price'] =  price_yearly

indiceCAC40_yearly = df.groupby('year')['Indice CAC40'].mean().round(3)
df_yearly['CAC40_basis_points']  = indiceCAC40_yearly

df_yearly.head(10)
# Out:
#       Dividend   Price  CAC40_basis_points
# year
# 1987     0.311  10.609            1321.470
# 1988     0.323   8.497            1229.658
# 1989     0.336  10.926            1750.667
# 1990     0.350  12.387            1859.954
# 1991     0.371  12.834            1764.264
# 1992     0.398  14.827            1846.913
# 1993     0.425  16.328            2012.700
# 1994     0.448  17.275            2065.525
# 1995     0.469  18.181            1869.042
# 1996     0.492  20.877            2082.438

# %%
# Calculate the necessary rates 
df_yearly['Dividend_Rate'] = np.log(df_yearly['Dividend']/df_yearly['Dividend'].shift(1)) # nbrepoints(t)/nbrepoints(t-1)
df_yearly['return_price'] = np.log(df_yearly['Price']/df_yearly['Price'].shift(1)) # p(t)/p(t-1)
df_yearly['return_CAC40'] = np.log(df_yearly['CAC40_basis_points']/df_yearly['CAC40_basis_points'].shift(1)) # nbrepoints(t)/nbrepoints(t-1)
df_yearly.head(10)
# Out:
#       Dividend   Price  CAC40_basis_points  Dividend_Rate  return_price  \
# year
# 1987     0.311  10.609            1321.470            NaN           NaN
# 1988     0.323   8.497            1229.658       0.037859     -0.221990
# 1989     0.336  10.926            1750.667       0.039459      0.251432
# 1990     0.350  12.387            1859.954       0.040822      0.125502
# 1991     0.371  12.834            1764.264       0.058269      0.035450
# 1992     0.398  14.827            1846.913       0.070250      0.144352
# 1993     0.425  16.328            2012.700       0.065637      0.096432
# 1994     0.448  17.275            2065.525       0.052704      0.056379
# 1995     0.469  18.181            1869.042       0.045810      0.051117
# 1996     0.492  20.877            2082.438       0.047876      0.138271
#
#       return_CAC40
# year
# 1987           NaN
# 1988     -0.072009
# 1989      0.353261
# 1990      0.060555
# 1991     -0.052818
# 1992      0.045782
# 1993      0.085962
# 1994      0.025907
# 1995     -0.099958
# 1996      0.108113

# %%
# Complete the missing values 
df_raw_part2 = pd.read_excel('séries_AirLiquide.xlsx',sheet_name ='part2')
df_raw_part2['year'] = df_raw_part2['year'].astype(str)
df_raw_part2.set_index('year',inplace = True)
# Calculate the necessary rates 
df_raw_part2['Dividend_Rate'] = np.log(df_raw_part2['Dividend']/df_raw_part2['Dividend'].shift(1)) # nbrepoints(t)/nbrepoints(t-1)
df_raw_part2['return_price'] = np.log(df_raw_part2['Price']/df_raw_part2['Price'].shift(1)) # p(t)/p(t-1)
df_raw_part2['return_CAC40'] = np.log(df_raw_part2['CAC40_basis_points']/df_raw_part2['CAC40_basis_points'].shift(1)) # nbrepoints(t)/nbrepoints(t-1)

# %%
# Drop the row 2020
df_raw_part2.drop(['2020'],axis = 0, inplace = True)
df_raw_part2
# Out:
#       Dividend   Price  CAC40_basis_points  Dividend_Rate  return_price  \
# year
# 2021     2.500  139.38              5256.0       0.003205      0.086088
# 2022     2.636  134.70              3942.0       0.052972     -0.034154
#
#       return_CAC40
# year
# 2021     -0.087364
# 2022     -0.287682

# %%
# Integrate the values to the data
df_yearly_1 = pd.concat([df_yearly,df_raw_part2], axis = 0)
df_yearly_1
# Out:
#       Dividend    Price  CAC40_basis_points  Dividend_Rate  return_price  \
# year
# 1987     0.311   10.609            1321.470            NaN           NaN
# 1988     0.323    8.497            1229.658       0.037859     -0.221990
# 1989     0.336   10.926            1750.667       0.039459      0.251432
# 1990     0.350   12.387            1859.954       0.040822      0.125502
# 1991     0.371   12.834            1764.264       0.058269      0.035450
# 1992     0.398   14.827            1846.913       0.070250      0.144352
# 1993     0.425   16.328            2012.700       0.065637      0.096432
# 1994     0.448   17.275            2065.525       0.052704      0.056379
# 1995     0.469   18.181            1869.042       0.045810      0.051117
# 1996     0.492   20.877            2082.438       0.047876      0.138271
# 1997     0.527   23.319            2732.165       0.068722      0.110620
# 1998     0.580   26.534            3659.463       0.095828      0.129158
# 1999     0.655   27.822            4464.609       0.121607      0.047400
# 2000     0.752   29.066            6353.173       0.138101      0.043742
# 2001     0.870   32.785            5085.517       0.145757      0.120402
# 2002     0.979   33.140            3866.780       0.118038      0.010770
# 2003     1.038   30.311            3115.573       0.058519     -0.089230
# 2004     1.027   33.690            3699.040      -0.010654      0.105690
# 2005     0.988   37.058            4247.107      -0.038715      0.095283
# 2006     1.009   44.525            5095.468       0.021032      0.183567
# 2007     1.103   52.345            5752.749       0.089074      0.161806
# 2008     1.228   51.069            4498.501       0.107353     -0.024679
# 2009     1.342   42.333            3303.648       0.088774     -0.187611
# 2010     1.437   56.202            3746.771       0.068397      0.283385
# 2011     1.539   62.257            3661.346       0.068575      0.102319
# 2012     1.655   66.713            3344.958       0.072668      0.069129
# 2013     1.774   71.813            3941.963       0.069436      0.073666
# 2014     1.886   75.452            4323.471       0.061221      0.049431
# 2015     1.995   91.099            4809.518       0.056186      0.188450
# 2016     2.096   78.093            4426.508       0.049387     -0.154046
# 2017     2.200   89.857            5164.833       0.048427      0.140319
# 2018     2.317   96.670            5310.646       0.051816      0.073084
# 2019     2.427  108.114            5381.491       0.046383      0.111883
# 2020     2.492  127.883            5735.843       0.026430      0.167930
# 2021     2.500  139.380            5256.000       0.003205      0.086088
# 2022     2.636  134.700            3942.000       0.052972     -0.034154
#
#       return_CAC40
# year
# 1987           NaN
# 1988     -0.072009
# 1989      0.353261
# 1990      0.060555
# 1991     -0.052818
# 1992      0.045782
# 1993      0.085962
# 1994      0.025907
# 1995     -0.099958
# 1996      0.108113
# 1997      0.271555
# 1998      0.292222
# 1999      0.198865
# 2000      0.352773
# 2001     -0.222558
# 2002     -0.273975
# 2003     -0.216009
# 2004      0.171660
# 2005      0.138165
# 2006      0.182113
# 2007      0.121326
# 2008     -0.245934
# 2009     -0.308717
# 2010      0.125867
# 2011     -0.023064
# 2012     -0.090377
# 2013      0.164225
# 2014      0.092380
# 2015      0.106538
# 2016     -0.082986
# 2017      0.154262
# 2018      0.027841
# 2019      0.013252
# 2020      0.063769
# 2021     -0.087364
# 2022     -0.287682

# %%
# Load french treasuries bonds and beta
french_bonds_rate =  pd.read_excel('tx_dintéret_OAT_1987_2022.xlsx',sheet_name = 'Final', header = None)
french_bonds_rate.columns = ['year','french_bonds_rate']
french_bonds_rate['year'] = french_bonds_rate['year'].astype(str)
french_bonds_rate.set_index('year', inplace = True)
print(french_bonds_rate)

beta =  pd.read_excel('beta_Air_liquide_1987_2022.xlsx', header = None)
beta.columns = ['year','beta']
beta['year'] = beta['year'].astype(str)
beta.set_index('year', inplace = True)
print(beta)
# Out:
#       french_bonds_rate
# year
# 1987           0.096800
# 1988           0.080000
# 1989           0.078000
# 1990           0.075000
# 1991           0.072000
# 1992           0.069000
# 1993           0.067000
# 1994           0.065000
# 1995           0.060000
# 1996           0.062000
# 1997           0.055000
# 1998           0.050000
# 1999           0.034100
# 2000           0.007000
# 2001           0.032800
# 2002           0.033100
# 2003           0.024500
# 2004           0.023700
# 2005           0.042100
# 2006           0.029100
# 2007           0.018750
# 2008           0.042343
# 2009           0.036488
# 2010           0.031170
# 2011           0.033211
# 2012           0.025360
# 2013           0.022044
# 2014           0.016664
# 2015           0.008419
# 2016           0.004679
# 2017           0.008099
# 2018           0.007841
# 2019           0.001302
# 2020          -0.001453
# 2021           0.007367
# 2022           0.017008
#        beta
# year
# 1987  0.990
# 1988  0.950
# 1989  1.220
# 1990  0.830
# 1991  1.510
# 1992  1.390
# 1993  1.060
# 1994  1.440
# 1995  0.900
# 1996  0.650
# 1997  0.540
# 1998  0.940
# 1999  1.040
# 2000  0.830
# 2001  0.700
# 2002  0.950
# 2003  0.540
# 2004  0.190
# 2005  0.960
# 2006  0.810
# 2007  0.360
# 2008  0.400
# 2009  0.660
# 2010  0.455
# 2011  0.414
# 2012  0.600
# 2013  0.332
# 2014  0.550
# 2015  0.250
# 2016  0.500
# 2017  0.650
# 2018  0.740
# 2019  0.910
# 2020  0.730
# 2021  0.810
# 2022  1.010

# %%
# Concatenate all our annual data
df_yearly_final = pd.concat([df_yearly_1,french_bonds_rate, beta], axis=1)
df_yearly_final
# Out:
#       Dividend    Price  CAC40_basis_points  Dividend_Rate  return_price  \
# year
# 1987     0.311   10.609            1321.470            NaN           NaN
# 1988     0.323    8.497            1229.658       0.037859     -0.221990
# 1989     0.336   10.926            1750.667       0.039459      0.251432
# 1990     0.350   12.387            1859.954       0.040822      0.125502
# 1991     0.371   12.834            1764.264       0.058269      0.035450
# 1992     0.398   14.827            1846.913       0.070250      0.144352
# 1993     0.425   16.328            2012.700       0.065637      0.096432
# 1994     0.448   17.275            2065.525       0.052704      0.056379
# 1995     0.469   18.181            1869.042       0.045810      0.051117
# 1996     0.492   20.877            2082.438       0.047876      0.138271
# 1997     0.527   23.319            2732.165       0.068722      0.110620
# 1998     0.580   26.534            3659.463       0.095828      0.129158
# 1999     0.655   27.822            4464.609       0.121607      0.047400
# 2000     0.752   29.066            6353.173       0.138101      0.043742
# 2001     0.870   32.785            5085.517       0.145757      0.120402
# 2002     0.979   33.140            3866.780       0.118038      0.010770
# 2003     1.038   30.311            3115.573       0.058519     -0.089230
# 2004     1.027   33.690            3699.040      -0.010654      0.105690
# 2005     0.988   37.058            4247.107      -0.038715      0.095283
# 2006     1.009   44.525            5095.468       0.021032      0.183567
# 2007     1.103   52.345            5752.749       0.089074      0.161806
# 2008     1.228   51.069            4498.501       0.107353     -0.024679
# 2009     1.342   42.333            3303.648       0.088774     -0.187611
# 2010     1.437   56.202            3746.771       0.068397      0.283385
# 2011     1.539   62.257            3661.346       0.068575      0.102319
# 2012     1.655   66.713            3344.958       0.072668      0.069129
# 2013     1.774   71.813            3941.963       0.069436      0.073666
# 2014     1.886   75.452            4323.471       0.061221      0.049431
# 2015     1.995   91.099            4809.518       0.056186      0.188450
# 2016     2.096   78.093            4426.508       0.049387     -0.154046
# 2017     2.200   89.857            5164.833       0.048427      0.140319
# 2018     2.317   96.670            5310.646       0.051816      0.073084
# 2019     2.427  108.114            5381.491       0.046383      0.111883
# 2020     2.492  127.883            5735.843       0.026430      0.167930
# 2021     2.500  139.380            5256.000       0.003205      0.086088
# 2022     2.636  134.700            3942.000       0.052972     -0.034154
#
#       return_CAC40  french_bonds_rate   beta
# year
# 1987           NaN           0.096800  0.990
# 1988     -0.072009           0.080000  0.950
# 1989      0.353261           0.078000  1.220
# 1990      0.060555           0.075000  0.830
# 1991     -0.052818           0.072000  1.510
# 1992      0.045782           0.069000  1.390
# 1993      0.085962           0.067000  1.060
# 1994      0.025907           0.065000  1.440
# 1995     -0.099958           0.060000  0.900
# 1996      0.108113           0.062000  0.650
# 1997      0.271555           0.055000  0.540
# 1998      0.292222           0.050000  0.940
# 1999      0.198865           0.034100  1.040
# 2000      0.352773           0.007000  0.830
# 2001     -0.222558           0.032800  0.700
# 2002     -0.273975           0.033100  0.950
# 2003     -0.216009           0.024500  0.540
# 2004      0.171660           0.023700  0.190
# 2005      0.138165           0.042100  0.960
# 2006      0.182113           0.029100  0.810
# 2007      0.121326           0.018750  0.360
# 2008     -0.245934           0.042343  0.400
# 2009     -0.308717           0.036488  0.660
# 2010      0.125867           0.031170  0.455
# 2011     -0.023064           0.033211  0.414
# 2012     -0.090377           0.025360  0.600
# 2013      0.164225           0.022044  0.332
# 2014      0.092380           0.016664  0.550
# 2015      0.106538           0.008419  0.250
# 2016     -0.082986           0.004679  0.500
# 2017      0.154262           0.008099  0.650
# 2018      0.027841           0.007841  0.740
# 2019      0.013252           0.001302  0.910
# 2020      0.063769          -0.001453  0.730
# 2021     -0.087364           0.007367  0.810
# 2022     -0.287682           0.017008  1.010

# %%
# Drop the row 1987
df_yearly_final.drop(['1987'], axis=0, inplace = True)
df_yearly_final.head(10)
# Out:
#       Dividend   Price  CAC40_basis_points  Dividend_Rate  return_price  \
# year
# 1988     0.323   8.497            1229.658       0.037859     -0.221990
# 1989     0.336  10.926            1750.667       0.039459      0.251432
# 1990     0.350  12.387            1859.954       0.040822      0.125502
# 1991     0.371  12.834            1764.264       0.058269      0.035450
# 1992     0.398  14.827            1846.913       0.070250      0.144352
# 1993     0.425  16.328            2012.700       0.065637      0.096432
# 1994     0.448  17.275            2065.525       0.052704      0.056379
# 1995     0.469  18.181            1869.042       0.045810      0.051117
# 1996     0.492  20.877            2082.438       0.047876      0.138271
# 1997     0.527  23.319            2732.165       0.068722      0.110620
#
#       return_CAC40  french_bonds_rate  beta
# year
# 1988     -0.072009              0.080  0.95
# 1989      0.353261              0.078  1.22
# 1990      0.060555              0.075  0.83
# 1991     -0.052818              0.072  1.51
# 1992      0.045782              0.069  1.39
# 1993      0.085962              0.067  1.06
# 1994      0.025907              0.065  1.44
# 1995     -0.099958              0.060  0.90
# 1996      0.108113              0.062  0.65
# 1997      0.271555              0.055  0.54

# %%
periods = 5
df_yearly_lisse = df_yearly_final
df_yearly_lisse = df_yearly_final.rolling(periods).mean()
df_yearly_lisse.head(10)
# Out:
#       Dividend    Price  CAC40_basis_points  Dividend_Rate  return_price  \
# year
# 1988       NaN      NaN                 NaN            NaN           NaN
# 1989       NaN      NaN                 NaN            NaN           NaN
# 1990       NaN      NaN                 NaN            NaN           NaN
# 1991       NaN      NaN                 NaN            NaN           NaN
# 1992    0.3556  11.8942           1690.2912       0.049332      0.066949
# 1993    0.3760  13.4604           1846.8996       0.054887      0.130634
# 1994    0.3984  14.7302           1909.8712       0.057536      0.091623
# 1995    0.4222  15.8890           1911.6888       0.058534      0.076746
# 1996    0.4464  17.4976           1975.3236       0.056455      0.097310
# 1997    0.4722  19.1960           2152.3740       0.056150      0.090564
#
#       return_CAC40  french_bonds_rate   beta
# year
# 1988           NaN                NaN    NaN
# 1989           NaN                NaN    NaN
# 1990           NaN                NaN    NaN
# 1991           NaN                NaN    NaN
# 1992      0.066954             0.0748  1.180
# 1993      0.098548             0.0722  1.202
# 1994      0.033078             0.0696  1.246
# 1995      0.000975             0.0666  1.260
# 1996      0.033161             0.0646  1.088
# 1997      0.078316             0.0618  0.918

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))

axes[0].plot(df_yearly_lisse.Dividend,df_yearly_lisse.Price)
axes[0].set_xlabel('Dividend')
axes[0].set_ylabel('Price')
axes[0].set_title('MA5')
axes[1].plot(df_yearly_final.Dividend,df_yearly_final.Price)
axes[1].set_xlabel('Dividend')
axes[1].set_ylabel('Price')
axes[1].set_title('Valeur observée')

axes[2].plot(df_yearly_lisse.Dividend,df_yearly_lisse.Price, '--r', )
axes[2].plot(df_yearly_final.Dividend,df_yearly_final.Price, '-b')
axes[2].set_xlabel('Dividend')
axes[2].set_ylabel('Price')
axes[2].legend(['MA5', 'Valeur observée'])

# %% [markdown]
# ### 4 - Estimation of the model

# %%
data = df_yearly_final

dividend = data['Dividend']
dividend_rate = data['Dividend_Rate']
price = data['Price']
return_CAC40 = data['return_CAC40']
french_bonds_rate = data['french_bonds_rate']
beta = data['beta']

Y = (dividend/price.shift(1))-french_bonds_rate
gt = dividend_rate

# Get rid of the nan values 
Y=Y[1:]
gt=gt[1:]

print(Y)
print(gt)
# Out:
# year
# 1989   -0.038457
# 1990   -0.042966
# 1991   -0.042049
# 1992   -0.037989
# 1993   -0.038336
# 1994   -0.037562
# 1995   -0.032851
# 1996   -0.034939
# 1997   -0.029757
# 1998   -0.025128
# 1999   -0.009415
# 2000    0.020029
# 2001   -0.002868
# 2002   -0.003239
# 2003    0.006822
# 2004    0.010182
# 2005   -0.012774
# 2006   -0.001872
# 2007    0.006023
# 2008   -0.018884
# 2009   -0.010210
# 2010    0.002775
# 2011   -0.005827
# 2012    0.001223
# 2013    0.004548
# 2014    0.009598
# 2015    0.018022
# 2016    0.018329
# 2017    0.020073
# 2018    0.017944
# 2019    0.023804
# 2020    0.024502
# 2021    0.012182
# 2022    0.001904
# dtype: float64
# year
# 1989    0.039459
# 1990    0.040822
# 1991    0.058269
# 1992    0.070250
# 1993    0.065637
# 1994    0.052704
# 1995    0.045810
# 1996    0.047876
# 1997    0.068722
# 1998    0.095828
# 1999    0.121607
# 2000    0.138101
# 2001    0.145757
# 2002    0.118038
# 2003    0.058519
# 2004   -0.010654
# 2005   -0.038715
# 2006    0.021032
# 2007    0.089074
# 2008    0.107353
# 2009    0.088774
# 2010    0.068397
# 2011    0.068575
# 2012    0.072668
# 2013    0.069436
# 2014    0.061221
# 2015    0.056186
# 2016    0.049387
# 2017    0.048427
# 2018    0.051816
# 2019    0.046383
# 2020    0.026430
# 2021    0.003205
# 2022    0.052972
# Name: Dividend_Rate, dtype: float64

# %% [markdown]
# #### 4-1 ARMA

# %%
# ARMA example
from statsmodels.tsa.arima.model import ARIMA
Y = Y.values
X = gt.values
# fit model
p = 2
d = 0 
q = 0
model_ARIMA = ARIMA(endog=Y, exog=X, order=(p, d, q))
fit_ARIMA = model_ARIMA.fit()
print(fit_ARIMA.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   34
# Model:                 ARIMA(2, 0, 0)   Log Likelihood                 105.815
# Date:                Wed, 09 Aug 2023   AIC                           -201.629
# Time:                        23:23:03   BIC                           -193.997
# Sample:                             0   HQIC                          -199.027
#                                  - 34
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0121      0.014     -0.866      0.386      -0.040       0.015
# x1             0.0288      0.062      0.464      0.643      -0.093       0.150
# ar.L1          0.7951      0.170      4.682      0.000       0.462       1.128
# ar.L2          0.0936      0.206      0.455      0.649      -0.309       0.496
# sigma2         0.0001   2.97e-05      3.738      0.000    5.27e-05       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.11   Jarque-Bera (JB):                 0.83
# Prob(Q):                              0.74   Prob(JB):                         0.66
# Heteroskedasticity (H):               1.21   Skew:                            -0.09
# Prob(H) (two-sided):                  0.76   Kurtosis:                         3.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
